# %% [markdown]
# This code aims to decode the XNAT Segmentation. The way XNAT store segmentations is to save it as a stacked version (all segmentations in all slices will be saved in one single dicom file, stacked on top of each othter).
#
# Step 1: Septate segmentation
# Step 2: Original Image
# Step 2: Map segment to the original image

# %% [markdown]
# # Step 1: Segmentation File

# %%
patient_directory=r"F:\XNAT_BACK\archive\PanCanAID\arc001\1000256"

import os
import xml.etree.ElementTree as ET
from typing import Optional, Dict, Any
import logging
import pydicom
# Configure logging
logging.basicConfig(level=logging.INFO)

# %% [markdown]
# ## Find assessor folder and segmentation info

# %%
def assessors_path(patient_directory: str) -> Optional[str]:
    """
    This function takes the path to a patient directory and returns the path of the ASSESSORS directory if it exists.
    
    Parameters:
    - patient_directory (str): The directory path of the patient.
    
    Returns:
    - Optional[str]: The path to the ASSESSORS directory if it exists, otherwise None.
    """
    assessors_dir = os.path.join(patient_directory, 'ASSESSORS')
    if not os.path.exists(assessors_dir):
        logging.info("No segmentation exists")
        return None
    logging.info(f"'ASSESSORS' folder exists: {assessors_dir}")
    return assessors_dir


def get_segmentations_from_assessors_path(assessors_path: str) -> Dict[str, Dict[str, Any]]:
    """
    This function searches the ASSESSORS folder and creates a dictionary of all segmentations.
    
    Parameters:
    - assessors_path (str): The path to the ASSESSORS directory.
    
    Returns:
    - Dict[str, Dict[str, Any]]: A dictionary with the name of the segmentor and datetime of segmentation as keys. 
      Each key maps to another dictionary containing 'created_by', 'created_time', 'dicom_name', and 'dicom_fullpath'.
    """
    segmentation_paths = [d for d in os.listdir(assessors_path) if os.path.isdir(os.path.join(assessors_path, d))]
    segmentations = {}

    for seg in segmentation_paths:
        seg_dir = os.path.join(assessors_path, seg, 'SEG')
        if os.path.exists(seg_dir):
            files = os.listdir(seg_dir)
            
            # Find XML files
            xml_files = [f for f in files if f.endswith('.xml')]
            
            for xml_file in xml_files:
                xml_path = os.path.join(seg_dir, xml_file)
                try:
                    # Parse the XML file
                    tree = ET.parse(xml_path)
                    root = tree.getroot()
                    
                    # Extract createdBy and createdTime
                    entry = root.find('.//cat:entry', namespaces={'cat': 'http://nrg.wustl.edu/catalog'})
                    if entry is not None:
                        created_by = entry.get('createdBy')
                        created_time = entry.get('createdTime')
                        dicom_name = entry.get('name')
                        dicom_fullpath = os.path.join(seg_dir, dicom_name)
                        
                        # Save to dictionary
                        key = f"{created_by}>>{created_time}"
                        segmentations[key] = {
                            'created_by': created_by,
                            'created_time': created_time,
                            'dicom_name': dicom_name,
                            'dicom_fullpath': dicom_fullpath
                        }
                        logging.info(segmentations[key])
                except ET.ParseError as e:
                    logging.error(f"Error parsing XML file {xml_file}: {e}")
                except Exception as e:
                    logging.error(f"Unexpected error: {e}")

    return segmentations

ass_path = assessors_path(patient_directory)                    
all_segmentation_dic = get_segmentations_from_assessors_path(ass_path)
all_segmentation_dic
# Out:
# INFO:root:No segmentation exists
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 73
#      70     return segmentations
#      72 ass_path = assessors_path(patient_directory)
# ---> 73 all_segmentation_dic = get_segmentations_from_assessors_path(ass_path)
#      74 all_segmentation_dic
#
# Cell In[2], line 30, in get_segmentations_from_assessors_path(assessors_path)
#      19 def get_segmentations_from_assessors_path(assessors_path: str) -> Dict[str, Dict[str, Any]]:
#      20     """
#      21     This function searches the ASSESSORS folder and creates a dictionary of all segmentations.
#      22
#    (...)
#      28       Each key maps to another dictionary containing 'created_by', 'created_time', 'dicom_name', and 'dicom_fullpath'.
#      29     """
# ---> 30     segmentation_paths = [d for d in os.listdir(assessors_path) if os.path.isdir(os.path.join(assessors_path, d))]
#      31     segmentations = {}
#      33     for seg in segmentation_paths:
#
# Cell In[2], line 30, in <listcomp>(.0)
#      19 def get_segmentations_from_assessors_path(assessors_path: str) -> Dict[str, Dict[str, Any]]:
#      20     """
#      21     This function searches the ASSESSORS folder and creates a dictionary of all segmentations.
#      22
#    (...)
#      28       Each key maps to another dictionary containing 'created_by', 'created_time', 'dicom_name', and 'dicom_fullpath'.
#      29     """
# ---> 30     segmentation_paths = [d for d in os.listdir(assessors_path) if os.path.isdir(os.path.join(assessors_path, d))]
#      31     segmentations = {}
#      33     for seg in segmentation_paths:
#
# File <frozen ntpath>:108, in join(path, *paths)
#
# TypeError: expected str, bytes or os.PathLike object, not NoneType

# %% [markdown]
# ## Select the desired segmentation

# %%
# here user should chose one of the segmetnations in the all_segmentation_dic
selected_segmentation= 'farzane_shoja>>2024-01-08T21:47:48.601'
selected_segmentation_dic = all_segmentation_dic[selected_segmentation]
selected_segmentation_dic
selected_dicom_fullpath = selected_segmentation_dic.get('dicom_fullpath')
selected_dicom_data = pydicom.dcmread(dicom_fullpath)
selected_dicom_data
# Out:
# Dataset.file_meta -------------------------------
# (0002, 0000) File Meta Information Group Length  UL: 220
# (0002, 0001) File Meta Information Version       OB: b'\x00\x01'
# (0002, 0002) Media Storage SOP Class UID         UI: Segmentation Storage
# (0002, 0003) Media Storage SOP Instance UID      UI: 2.25.491103861982319274517040568320756975749
# (0002, 0010) Transfer Syntax UID                 UI: Explicit VR Little Endian
# (0002, 0012) Implementation Class UID            UI: 2.25.80302813137786398554742050926734630921603366648225212145404
# (0002, 0013) Implementation Version Name         SH: 'dcmjs-0.0'
# -------------------------------------------------
# (0008, 0008) Image Type                          CS: ['DERIVED', 'PRIMARY']
# (0008, 0016) SOP Class UID                       UI: Segmentation Storage
# (0008, 0018) SOP Instance UID                    UI: 2.25.491103861982319274517040568320756975749
# (0008, 0020) Study Date                          DA: '20171119'
# (0008, 0021) Series Date                         DA: '20240109'
# (0008, 0023) Content Date                        DA: '20240109'
# (0008, 0030) Study Time                          TM: '011739'
# (0008, 0031) Series Time                         TM: '011733'
# (0008, 0033) Content Time                        TM: '011733'
# (0008, 0050) Accession Number                    SH: 'SQ5MR4DE3Y9P'
# (0008, 0060) Modality                            CS: 'SEG'
# (0008, 0070) Manufacturer                        LO: 'GE MEDICAL SYSTEMS'
# (0008, 0090) Referring Physician's Name          PN: ''
# (0008, 103e) Series Description                  LO: 'Shoja'
# (0008, 1090) Manufacturer's Model Name           LO: 'LightSpeed VCT'
# (0008, 1115)  Referenced Series Sequence  1 item(s) ----
#    (0008, 114a)  Referenced Instance Sequence  35 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1223550322401514531650375185016516061895
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1126274488418062869199659005598145704391
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1275393837023191675984436635106049455819
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1026694813442786965655182099651166547837
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1197697044274388421396809739181754264644
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1137178868985010808179938507364017428378
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1037764792917859009979328356938590579671
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1140572070325262502280951912450891661704
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1259084533646119940539609703664840656182
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1304922298154011860150296433797188269011
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1088014641999050191606694600151094230387
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1285649527097752865715450035530075414079
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1068824965643336226941123446218241745717
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1178052975659132540887191840076347319052
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1325048363057576439622051856261397051526
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1189567169181301475466003993408008252448
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1330477512338080882086253530518146592033
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1329709063977604760460821107035702413842
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1028585832276030797708037729059225702196
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1066351023013865432875171224629300426476
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1117805653918157427384935593038816204656
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1162217491517961308482545596587867064272
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1059278036909052283552515404725724013598
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1249026267077346072500997066969835044622
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1068824279358674881433793958415720261364
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1293554375367321865712132963170252787381
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1318726339155567525845264318009178105212
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1295528052357794417995298866454637831673
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1149780189644448331346142205841863065571
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1100930145125379551829278936268922198610
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1290023059633359434211901632841957863057
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1301998513122216808982237905930371369920
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1010983957169523704819205510363115856288
#       ---------
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1206215289102999158247338341006611755149
#       ---------
#    (0020, 000e) Series Instance UID                 UI: 2.1100300992007311008203390087720826254277
#    ---------
# (0010, 0010) Patient's Name                      PN: '1000256'
# (0010, 0020) Patient ID                          LO: '1000256'
# (0010, 0030) Patient's Birth Date                DA: ''
# (0010, 0040) Patient's Sex                       CS: 'F'
# (0010, 1010) Patient's Age                       AS: '036Y'
# (0018, 1000) Device Serial Number                LO: '1'
# (0018, 1020) Software Versions                   LO: '07MW18.4'
# (0018, 9004) Content Qualification               CS: 'RESEARCH'
# (0020, 000d) Study Instance UID                  UI: 2.1046963116325084910325315933509170595300
# (0020, 000e) Series Instance UID                 UI: 2.25.187300731839922871428271513585315129074
# (0020, 0010) Study ID                            SH: 'P75XXGMK42C8'
# (0020, 0011) Series Number                       IS: '99'
# (0020, 0013) Instance Number                     IS: '1'
# (0020, 0052) Frame of Reference UID              UI: 2.1034875255693369107331141915883459460410
# (0020, 1040) Position Reference Indicator        LO: 'XY'
# (0020, 4000) Image Comments                      LT: Array of 20 elements
# (0020, 9221)  Dimension Organization Sequence  1 item(s) ----
#    (0020, 9164) Dimension Organization UID          UI: 2.25.550391960723460406143934620210839840549
#    ---------
# (0020, 9222)  Dimension Index Sequence  2 item(s) ----
#    (0020, 9164) Dimension Organization UID          UI: 2.25.550391960723460406143934620210839840549
#    (0020, 9165) Dimension Index Pointer             AT: (0062, 000b)
#    (0020, 9167) Functional Group Pointer            AT: (0062, 000a)
#    (0020, 9421) Dimension Description Label         LO: 'ReferencedSegmentNumber'
#    ---------
#    (0020, 9164) Dimension Organization UID          UI: 2.25.550391960723460406143934620210839840549
#    (0020, 9165) Dimension Index Pointer             AT: (0020, 0032)
#    (0020, 9167) Functional Group Pointer            AT: (0020, 9113)
#    (0020, 9421) Dimension Description Label         LO: 'ImagePositionPatient'
#    ---------
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0008) Number of Frames                    IS: '23'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0100) Bits Allocated                      US: 1
# (0028, 0101) Bits Stored                         US: 1
# (0028, 0102) High Bit                            US: 0
# (0028, 0103) Pixel Representation                US: 0
# (0028, 2110) Lossy Image Compression             CS: '00'
# (0062, 0001) Segmentation Type                   CS: 'BINARY'
# (0062, 0002)  Segment Sequence  2 item(s) ----
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'T-D0050'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Tissue'
#       ---------
#    (0062, 0004) Segment Number                      US: 1
#    (0062, 0005) Segment Label                       LO: 'P'
#    (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
#    (0062, 000d) Recommended Display CIELab Value    US: [128, 174, 128]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'T-D0050'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Tissue'
#       ---------
#    ---------
#    (0062, 0003)  Segmented Property Category Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'T-D0050'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Tissue'
#       ---------
#    (0062, 0004) Segment Number                      US: 2
#    (0062, 0005) Segment Label                       LO: 'M'
#    (0062, 0008) Segment Algorithm Type              CS: 'MANUAL'
#    (0062, 000d) Recommended Display CIELab Value    US: [128, 174, 128]
#    (0062, 000f)  Segmented Property Type Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: 'T-D0050'
#       (0008, 0102) Coding Scheme Designator            SH: 'SRT'
#       (0008, 0104) Code Meaning                        LO: 'Tissue'
#       ---------
#    ---------
# (0070, 0080) Content Label                       CS: 'SEGMENTATION'
# (0070, 0081) Content Description                 LO: ''
# (0070, 0084) Content Creator's Name              PN: ''
# (5200, 9229)  Shared Functional Groups Sequence  1 item(s) ----
#    (0020, 9116)  Plane Orientation Sequence  1 item(s) ----
#       (0020, 0037) Image Orientation (Patient)         DS: [1, 0, 0, 0, 1, 0]
#       ---------
#    (0028, 9110)  Pixel Measures Sequence  1 item(s) ----
#       (0018, 0050) Slice Thickness                     DS: '6.5'
#       (0018, 0088) Spacing Between Slices              DS: '6.5'
#       (0028, 0030) Pixel Spacing                       DS: [0.703125, 0.703125]
#       ---------
#    ---------
# (5200, 9230)  Per-frame Functional Groups Sequence  23 item(s) ----
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 16]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -121.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1189567169181301475466003993408008252448
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 17]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -128]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1330477512338080882086253530518146592033
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 18]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -134.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1329709063977604760460821107035702413842
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 19]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -141]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1028585832276030797708037729059225702196
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 20]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -147.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1066351023013865432875171224629300426476
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 21]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -154]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1117805653918157427384935593038816204656
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 22]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -160.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1162217491517961308482545596587867064272
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 23]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -167]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1059278036909052283552515404725724013598
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 24]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -173.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1249026267077346072500997066969835044622
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [1, 25]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -180]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 1
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1140572070325262502280951912450891661704
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 8]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -69.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1259084533646119940539609703664840656182
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 9]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -76]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1304922298154011860150296433797188269011
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 10]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -82.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1088014641999050191606694600151094230387
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 11]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -89]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1285649527097752865715450035530075414079
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 12]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -95.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1068824965643336226941123446218241745717
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 13]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -102]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1178052975659132540887191840076347319052
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 14]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -108.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1325048363057576439622051856261397051526
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 15]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -115]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 16]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -121.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1189567169181301475466003993408008252448
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 17]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -128]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1330477512338080882086253530518146592033
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 18]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -134.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1329709063977604760460821107035702413842
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 19]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -141]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
#    (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#       (0008, 2112)  Source Image Sequence  1 item(s) ----
#          (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#          (0008, 1155) Referenced SOP Instance UID         UI: 2.1028585832276030797708037729059225702196
#          (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#             (0008, 0100) Code Value                          SH: '121322'
#             (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#             (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#             ---------
#          ---------
#       (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '113076'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Segmentation'
#          ---------
#       ---------
#    (0020, 9111)  Frame Content Sequence  1 item(s) ----
#       (0020, 9157) Dimension Index Values              UL: [2, 20]
#       ---------
#    (0020, 9113)  Plane Position Sequence  1 item(s) ----
#       (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -147.5]
#       ---------
#    (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#       (0062, 000b) Referenced Segment Number           US: 2
#       ---------
#    ---------
# (7fe0, 0010) Pixel Data                          OW: Array of 753664 elements

# %% [markdown]
# ## Get data of segmentation dicom
#
# - extract_referenced_sop_instance_uids
# - create_segment_number_to_label_map

# %%
def get_nested_element(dataset, tags):
    """
    Navigate through the DICOM dataset using a list of tags and return the final element.

    Parameters:
        dataset (pydicom.dataset.Dataset): The DICOM dataset.
        tags (list): A list of tuples representing the tags to navigate through.

    Returns:
        The final element in the DICOM dataset specified by the tags.
    """
    current_element = dataset
    for tag in tags:
        tag = pydicom.tag.Tag(tag)
        if tag in current_element:
            current_element = current_element[tag]
        else:
            raise KeyError(f"Tag {tag} not found in the dataset.")
        
        # If the current element is a sequence, assume we want the first item
        if isinstance(current_element, pydicom.sequence.Sequence):
            if len(current_element) > 0:
                current_element = current_element[0]
            else:
                raise ValueError(f"Sequence at tag {tag} is empty.")
    
    return current_element

def extract_referenced_sop_instance_uids(segmentation_dicom) -> list:
    """
    Extract a list of Referenced SOP Instance UIDs from a DICOM segmentation dataset.

    Parameters:
        segmentation_dicom (pydicom.dataset.Dataset): The DICOM dataset containing segmentation data.

    Returns:
        list: A list of Referenced SOP Instance UIDs.
    """
    referenced_sop_instance_uids = []
    try:
        referenced_series_sequence = get_nested_element(segmentation_dicom, [(0x0008, 0x1115)])
        for series_instance in referenced_series_sequence:
            if 'ReferencedInstanceSequence' in series_instance:
                for ref_instance in series_instance.ReferencedInstanceSequence:
                    if (0x0008, 0x1155) in ref_instance:
                        sop_instance_uid = ref_instance[(0x0008, 0x1155)].value
                        referenced_sop_instance_uids.append(sop_instance_uid)
        logging.info(f"Number of Referenced SOP Instance UIDs: {len(referenced_sop_instance_uids)}")
    except (KeyError, ValueError) as e:
        logging.error(f"Error extracting Referenced SOP Instance UIDs: {e}")
    return referenced_sop_instance_uids

def create_segment_number_to_label_map(segmentation_dicom) -> dict:
    """
    Create a dictionary mapping Segment Number to Segment Label from a DICOM segmentation object.

    Parameters:
        segmentation_dicom (pydicom.dataset.Dataset): The DICOM dataset containing segmentation data.

    Returns:
        dict: A dictionary mapping Segment Number (int) to Segment Label (str).
    """
    segment_map = {}
    try:
        segment_sequence = get_nested_element(segmentation_dicom, [(0x0062, 0x0002)])
        for item in segment_sequence:
            if (0x0062, 0x0004) in item and (0x0062, 0x0005) in item:
                segment_number = item[(0x0062, 0x0004)].value
                segment_label = item[(0x0062, 0x0005)].value
                segment_map[segment_number] = segment_label
        logging.info(f"Segment map: {segment_map}")
    except (KeyError, ValueError) as e:
        logging.error(f"Error creating segment map: {e}")
    return segment_map

list_refSOPinstanceUID = extract_referenced_sop_instance_uids(selected_dicom_data)
segment_map = create_segment_number_to_label_map(selected_dicom_data)
# Out:
# INFO:root:Number of Referenced SOP Instance UIDs: 35
# INFO:root:Segment map: {1: 'P', 2: 'M'}

# %%
referenced_series_sequence = get_nested_element(segmentation_dicom, [(0x0008, 0x1115)])
        for series_instance in referenced_series_sequence:
            if 'ReferencedInstanceSequence' in series_instance:
                for ref_instance in series_instance.ReferencedInstanceSequence:
                    if (0x0008, 0x1155) in ref_instance:
                        sop_instance_uid = ref_instance[(0x0008, 0x1155)].value
                        referenced_sop_instance_uids.append(sop_instance_uid)

# %%
segmentation_dicom = selected_dicom_data
per_frame_group_seq= get_nested_element(segmentation_dicom , [(0x5200,0x9230)])
for der_image_seq in per_frame_group_seq:
    print(der_image_seq)
# Out:
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 16]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -121.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1189567169181301475466003993408008252448
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 17]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -128]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1330477512338080882086253530518146592033
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 18]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -134.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1329709063977604760460821107035702413842
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 19]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -141]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1028585832276030797708037729059225702196
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 20]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -147.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1066351023013865432875171224629300426476
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 21]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -154]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1117805653918157427384935593038816204656
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 22]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -160.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1162217491517961308482545596587867064272
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 23]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -167]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1059278036909052283552515404725724013598
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 24]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -173.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1249026267077346072500997066969835044622
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 25]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -180]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1140572070325262502280951912450891661704
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 8]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -69.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1259084533646119940539609703664840656182
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 9]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -76]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1304922298154011860150296433797188269011
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 10]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -82.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1088014641999050191606694600151094230387
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 11]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -89]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1285649527097752865715450035530075414079
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 12]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -95.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1068824965643336226941123446218241745717
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 13]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -102]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1178052975659132540887191840076347319052
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 14]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -108.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1325048363057576439622051856261397051526
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 15]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -115]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 16]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -121.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1189567169181301475466003993408008252448
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 17]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -128]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1330477512338080882086253530518146592033
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 18]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -134.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1329709063977604760460821107035702413842
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 19]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -141]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1028585832276030797708037729059225702196
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [2, 20]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -147.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 2
#    ---------

# %%
per_frame_group_seq[0]
# Out:
# (0008, 9124)  Derivation Image Sequence  1 item(s) ----
#    (0008, 2112)  Source Image Sequence  1 item(s) ----
#       (0008, 1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008, 1155) Referenced SOP Instance UID         UI: 2.1298488738111743097671400985957233014971
#       (0040, a170)  Purpose of Reference Code Sequence  1 item(s) ----
#          (0008, 0100) Code Value                          SH: '121322'
#          (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#          (0008, 0104) Code Meaning                        LO: 'Source image for image processing operation'
#          ---------
#       ---------
#    (0008, 9215)  Derivation Code Sequence  1 item(s) ----
#       (0008, 0100) Code Value                          SH: '113076'
#       (0008, 0102) Coding Scheme Designator            SH: 'DCM'
#       (0008, 0104) Code Meaning                        LO: 'Segmentation'
#       ---------
#    ---------
# (0020, 9111)  Frame Content Sequence  1 item(s) ----
#    (0020, 9157) Dimension Index Values              UL: [1, 16]
#    ---------
# (0020, 9113)  Plane Position Sequence  1 item(s) ----
#    (0020, 0032) Image Position (Patient)            DS: [-170.1, -180, -121.5]
#    ---------
# (0062, 000a)  Segment Identification Sequence  1 item(s) ----
#    (0062, 000b) Referenced Segment Number           US: 1
#    ---------

# %%
original_CT_path =
